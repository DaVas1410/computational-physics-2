# %%
import magnetic as mg

# %%
help(mg)
# Out:
# Help on package magnetic:
#
# NAME
#     magnetic
#
# PACKAGE CONTENTS
#     m
#     m2
#     magnetic
#     magnetic_wtests
#
# CLASSES
#     builtins.object
#         magnetic.magnetic.MagneticField2D
#
#     class MagneticField2D(builtins.object)
#      |  MagneticField2D(x_l=-10.0, x_r=10, y_l=-10, y_r=10, n=50)
#      |
#      |  TBA
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, x_l=-10.0, x_r=10, y_l=-10, y_r=10, n=50)
#      |
#      |  grid_generator(self)
#      |
#      |  plot_2dfield(self, field_type='uniform')
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods defined here:
#      |
#      |  dipolar_bfield(x_2d, y_2d)
#      |
#      |  uniform_bfield(x_2d, y_2d)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables
#      |
#      |  __weakref__
#      |      list of weak references to the object
#
# DATA
#     __all__ = ['MagneticField2D']
#
# FILE
#     /Users/wbandabarragan/Library/CloudStorage/Dropbox/GitHub_Repos/computational-physics-2/unit-2/magnetic-dev/magnetic/__init__.py

# %%
mag = mg.MagneticField2D(x_l = -20, x_r = +20, y_l = -20, y_r = +20, n = 120)

xx, yy = mag.grid_generator()

# %%
b_r, b_theta = mag.dipolar_bfield(xx, yy)

# %%
mag.plot_2dfield(field_type="dipolar")
